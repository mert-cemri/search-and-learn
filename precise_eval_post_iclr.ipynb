# %%
## apply prm on solutions

# %%
from eval_utils import load_jsonl, get_success

# %%
soft_beam = (0.71, 3.8)
beam = (0.71, 3.2)
speculative_beam = (0.73, 8.65) #31159.16
import pandas as pd

data = {
    "Method": ["Soft Beam", "Beam", "Speculative Beam"],
    "Accuracy": [soft_beam[0], beam[0], speculative_beam[0]],
    "Time": [soft_beam[1], beam[1], speculative_beam[1]]
}

df = pd.DataFrame(data)
df.set_index("Method", inplace=True)
df
# Out:
#                   Accuracy  Time
# Method
# Soft Beam             0.71  3.80
# Beam                  0.71  3.20
# Speculative Beam      0.73  8.65

# %%
soft_beam_search_qwen_online = "/data/mert_cemri/spec/search-and-learn/data_post_iclr/beam_search/QwenQwen2.5-Math-1.5B-Instruct-_n4_b0.1_q500_period0_model_lenNone.jsonl"
samples_soft_beam_search_qwen_online = list(load_jsonl(soft_beam_search_qwen_online))
results_soft_beam_search_qwen_online = get_success(samples_soft_beam_search_qwen_online)
results_soft_beam_search_qwen_online
# Out:
# 100%|██████████| 500/500 [00:01<00:00, 310.10it/s]
# 0.71

# %%
online_speculative_beam_search_500_b20 = "/data/mert_cemri/spec/search-and-learn/data_post_iclr/online_speculative_beam_search/QwenQwen2.5-Math-1.5B-Instruct-QwenQwen2.5-Math-7B-Instruct_n4_b20.0_q500_period0_t1024_num_iters20_model_lenNone.jsonl"
samples_online_speculative_beam_search_500_b20 = list(load_jsonl(online_speculative_beam_search_500_b20))
results_online_speculative_beam_search_500_b20 = get_success(samples_online_speculative_beam_search_500_b20)
results_online_speculative_beam_search_500_b20
# Out:
# ...
# 100%|██████████| 500/500 [00:01<00:00, 272.16it/s]
# 0.704

# %%
beam_search_qwen_online_500 = "/data/mert_cemri/spec/search-and-learn/data_post_iclr/beam_search/QwenQwen2.5-Math-1.5B-Instruct-_n4_b0.1_q500_period0_model_lenNone.jsonl"
samples_beam_search_qwen_online_500 = list(load_jsonl(beam_search_qwen_online_500))
results_beam_search_qwen_online_500 = get_success(samples_beam_search_qwen_online_500)
results_beam_search_qwen_online_500
# Out:
# 100%|██████████| 500/500 [00:01<00:00, 275.63it/s]
# 0.71

# %%
beam_search_qwen_offline = "/data/mert_cemri/spec/search-and-learn/data_post_iclr/online_speculative_beam_search/QwenQwen2.5-Math-1.5B-Instruct-QwenQwen2.5-Math-7B-Instruct_n4_b50.0_q20_period0_t1024_num_iters20_model_lenNone.jsonl"
samples_beam_search_qwen_offline = list(load_jsonl(beam_search_qwen_offline))
results_beam_search_qwen_offline = get_success(samples_beam_search_qwen_offline[:10])
results_beam_search_qwen_offline
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 289.19it/s]
# 0.8

# %%
spec_align_merged_1b_7b_b005_1 = "/data/user_data/mert/spec/search-and-learn/data_post_iclr/speculative_beam_search_merged_models/AMead10Llama-3.2-1B-Instruct-AWQ-_n4_b0.05_q10_period0_model_len10000.jsonl"
spec_align_merged_1b_7b_b005_2 = "/data/user_data/mert/spec/search-and-learn/data_post_iclr/speculative_beam_search_merged_models/AMead10Llama-3.2-1B-Instruct-AWQ-_n4_b0.05_q8_period0_model_len10000.jsonl"
spec_align_merged_1b_7b_b005_3 = "/data/user_data/mert/spec/search-and-learn/data_post_iclr/speculative_beam_search_merged_models/AMead10Llama-3.2-1B-Instruct-AWQ-_n4_b0.05_q6_period0_model_len10000.jsonl"
spec_align_merged_1b_7b_b005_4 = "/data/user_data/mert/spec/search-and-learn/data_post_iclr/speculative_beam_search_merged_models/AMead10Llama-3.2-1B-Instruct-AWQ-_n4_b0.05_q3_period0_model_len10000.jsonl"
samples_spec_align_merged_1b_7b_b005 = list(load_jsonl(spec_align_merged_1b_7b_b005_1)) + list(load_jsonl(spec_align_merged_1b_7b_b005_2)) + list(load_jsonl(spec_align_merged_1b_7b_b005_3)) + list(load_jsonl(spec_align_merged_1b_7b_b005_4))
results_spec_align_merged_1b_7b_b005 = get_success(samples_spec_align_merged_1b_7b_b005[:10])
results_spec_align_merged_1b_7b_b005
# Out:
# ...
# 100%|██████████| 10/10 [00:00<00:00, 114.77it/s]
# 0.5

# %%
beam_search_qwen_online = "/data/user_data/mert/spec/search-and-learn/data_post_iclr/online_speculative_beam_search/QwenQwen2.5-Math-1.5B-Instruct-_n4_b0.0_q20_period0_t1024_num_iters20_model_len10000.jsonl"
samples_beam_search_qwen_online = list(load_jsonl(beam_search_qwen_online))
results_beam_search_qwen_online = get_success(samples_beam_search_qwen_online[:20])
results_beam_search_qwen_online
# Out:
# 100%|██████████| 20/20 [00:00<00:00, 176.76it/s]
# 0.9

# %%
spec_align_merged_3b_7b = "/data/user_data/mert/spec/search-and-learn/data_post_iclr/speculative_beam_search_merged_models/AMead10Llama-3.2-3B-Instruct-AWQ-_n4_b0.05_q10_period0_model_len10000.jsonl"
samples_spec_align_merged_3b_7b_005 = list(load_jsonl(spec_align_merged_3b_7b))
results_spec_align_merged_3b_7b_005 = get_success(samples_spec_align_merged_3b_7b_005[:10])
results_spec_align_merged_3b_7b_005
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 112.78it/s]
# 0.4

# %%
spec_align_merged_3b_7b_05 = "/data/user_data/mert/spec/search-and-learn/data_post_iclr/speculative_beam_search_merged_models/AMead10Llama-3.2-3B-Instruct-AWQ-_n4_b0.5_q10_period0_model_len10000.jsonl"
samples_spec_align_merged_3b_7b_05 = list(load_jsonl(spec_align_merged_3b_7b_05))
results_spec_align_merged_3b_7b_05 = get_success(samples_spec_align_merged_3b_7b_05[:10])
results_spec_align_merged_3b_7b_05
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 102.90it/s]
# 0.4

# %%
spec_align_merged_1b_7b_b30_1 = "/data/user_data/mert/spec/search-and-learn/data_post_iclr/speculative_beam_search_merged_models/AMead10Llama-3.2-3B-Instruct-AWQ-_n4_b30.0_q6_period0_model_len10000.jsonl"
spec_align_merged_1b_7b_b30_2 = "/data/user_data/mert/spec/search-and-learn/data_post_iclr/speculative_beam_search_merged_models/AMead10Llama-3.2-3B-Instruct-AWQ-_n4_b30.0_q11_period0_model_len10000.jsonl"
samples_spec_align_merged_1b_7b_b30 = list(load_jsonl(spec_align_merged_1b_7b_b30_1)) + list(load_jsonl(spec_align_merged_1b_7b_b30_2))
results_spec_align_merged_1b_7b_b30 = get_success(samples_spec_align_merged_1b_7b_b30[:10])
results_spec_align_merged_1b_7b_b30
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 112.22it/s]
# 0.4

# %%
spec_align_merged_1b_7b_b001 = "/data/user_data/mert/spec/search-and-learn/data_post_iclr/speculative_beam_search_merged_models/AMead10Llama-3.2-1B-Instruct-AWQ-_n4_b0.01_q10_period0_model_len10000.jsonl"
spec_align_merged_1b_7b_b0001 = "/data/user_data/mert/spec/search-and-learn/data_post_iclr/speculative_beam_search_merged_models/AMead10Llama-3.2-1B-Instruct-AWQ-_n4_b0.001_q10_period0_model_len10000.jsonl"

# %%
beam_search_n4_3b = "/data/user_data/mert/spec/search-and-learn/data_clean/beam_search/AMead10Llama-3.2-3B-Instruct-AWQ-_n4_b0.1_q500_period0_model_len10000.jsonl"
beam_search_n2_3b = "/data/user_data/mert/spec/search-and-learn/data_clean/beam_search/AMead10Llama-3.2-3B-Instruct-AWQ-_n2_b0.1_q500_period0_model_len10000.jsonl"
beam_search_n4_1b = "/data/user_data/mert/spec/search-and-learn/data_post_iclr/beam_search/AMead10Llama-3.2-1B-Instruct-AWQ-_n4_b0.1_q500_period0_model_len10000.jsonl"
beam_search_n4_7b = "/data/user_data/mert/spec/search-and-learn/data_post_iclr/beam_search/QwenQwen2.5-7B-Instruct-_n4_b0.1_q10_period0_model_lenNone.jsonl"

cot_8b = "/data/user_data/mert/spec/search-and-learn/data_iclr/best_of_n/hugging-quantsMeta-Llama-3.1-8B-Instruct-AWQ-INT4-_n1_b0.1_q500_period0_model_len10000.jsonl"
cot_3b = "/data/user_data/mert/spec/search-and-learn/data_iclr/best_of_n/AMead10Llama-3.2-3B-Instruct-AWQ-_n1_b0.1_q500_period0_model_len10000.jsonl"

spec_align_n8_p0_b15 = "/data/user_data/mert/spec/search-and-learn/data_post_iclr/speculative_beam_search/AMead10Llama-3.2-1B-Instruct-AWQ-AMead10Llama-3.2-3B-Instruct-AWQ_n8_b1.5_q100_period0_model_len6000.jsonl"
spec_align_n4_p0_b15 = "/data/user_data/mert/spec/search-and-learn/data_post_iclr/speculative_beam_search/AMead10Llama-3.2-1B-Instruct-AWQ-AMead10Llama-3.2-3B-Instruct-AWQ_n4_b1.5_q100_period0_model_len6000.jsonl"
spec_align_n8_p0_b3 = "/data/user_data/mert/spec/search-and-learn/data_post_iclr/speculative_beam_search/AMead10Llama-3.2-1B-Instruct-AWQ-AMead10Llama-3.2-3B-Instruct-AWQ_n8_b3.0_q100_period0_model_len6000.jsonl"
spec_align_n8_p0_b1 = "/data/user_data/mert/spec/search-and-learn/data_post_iclr/speculative_beam_search/AMead10Llama-3.2-1B-Instruct-AWQ-AMead10Llama-3.2-3B-Instruct-AWQ_n8_b1.0_q100_period0_model_len6000.jsonl"

# %%
samples_spec_align_merged_1b_7b_b001 = list(load_jsonl(spec_align_merged_1b_7b_b001))
results_spec_align_merged_1b_7b_b001 = get_success(samples_spec_align_merged_1b_7b_b001[:]), 246.63

samples_spec_align_merged_1b_7b_b0001 = list(load_jsonl(spec_align_merged_1b_7b_b0001))
results_spec_align_merged_1b_7b_b0001 = get_success(samples_spec_align_merged_1b_7b_b0001[:]), 236.32
# Out:
# ...
# 100%|██████████| 10/10 [00:00<00:00, 50.10it/s]

# %%
# Load and process beam search files
samples_beam_search_n4_3b = list(load_jsonl(beam_search_n4_3b))
results_beam_search_n4_3b = get_success(samples_beam_search_n4_3b[:10]), 2910.9

samples_beam_search_n2_3b = list(load_jsonl(beam_search_n2_3b))
results_beam_search_n2_3b = get_success(samples_beam_search_n2_3b[:10]), 2910.9

samples_beam_search_n4_1b = list(load_jsonl(beam_search_n4_1b))
results_beam_search_n4_1b = get_success(samples_beam_search_n4_1b[:10]), 2910.9

samples_beam_search_n4_7b = list(load_jsonl(beam_search_n4_7b))
results_beam_search_n4_7b = get_success(samples_beam_search_n4_7b[:10]), 2910.9
# Load and process CoT files
samples_cot_8b = list(load_jsonl(cot_8b))
results_cot_8b = get_success(samples_cot_8b), 2910.9

samples_cot_3b = list(load_jsonl(cot_3b))
results_cot_3b = get_success(samples_cot_3b), 2910.9

# Load and process speculative alignment files
samples_spec_align_n8_p0_b15 = list(load_jsonl(spec_align_n8_p0_b15))
results_spec_align_n8_p0_b15 = get_success(samples_spec_align_n8_p0_b15[:10]), 2910.9

samples_spec_align_n4_p0_b15 = list(load_jsonl(spec_align_n4_p0_b15))
results_spec_align_n4_p0_b15 = get_success(samples_spec_align_n4_p0_b15[:10]), 2910.9

samples_spec_align_n8_p0_b3 = list(load_jsonl(spec_align_n8_p0_b3))
results_spec_align_n8_p0_b3 = get_success(samples_spec_align_n8_p0_b3[:10]), 2910.9

samples_spec_align_n8_p0_b1 = list(load_jsonl(spec_align_n8_p0_b1))
results_spec_align_n8_p0_b1 = get_success(samples_spec_align_n8_p0_b1[:10]), 2910.9
# Out:
# ...
# 100%|██████████| 10/10 [00:00<00:00, 80.43it/s]

# %%
3000

# %%
120

# %%
# Print all results
print("Beam search results:")
print(f"n2 3B: {results_beam_search_n4_3b}")
print(f"n4 3B: {results_beam_search_n2_3b}")
print(f"n4 1B: {results_beam_search_n4_1b}")
print(f"n4 7B: {results_beam_search_n4_7b}")
print("\nCoT results:")
print(f"8B: {results_cot_8b}")
print(f"3B: {results_cot_3b}")
print("\nSpeculative alignment results:")
print(f"n8 b1.5: {results_spec_align_n8_p0_b15}")
print(f"n4 b1.5: {results_spec_align_n4_p0_b15}")
print(f"n8 b3.0: {results_spec_align_n8_p0_b3}")
print(f"n8 b1.0: {results_spec_align_n8_p0_b1}")
print("\n Merged 1B-7B results:")
print(f"b0.01: {results_spec_align_merged_1b_7b_b001}")
# print(f"b0.001: {results_spec_align_merged_1b_7b_b0001}")
# Out:
# Beam search results:
# n2 3B: (0.5, 2910.9)
# n4 3B: (0.6, 2910.9)
# n4 1B: (0.5, 2910.9)
# n4 7B: (0.8, 2910.9)
#
# CoT results:
# 8B: (0.404, 2910.9)
# 3B: (0.432, 2910.9)
#
# Speculative alignment results:
# n8 b1.5: (0.5, 2910.9)
# n4 b1.5: (0.5, 2910.9)
# n8 b3.0: (0.5, 2910.9)
# n8 b1.0: (0.4, 2910.9)
#
#  Merged 1B-7B results:
# b0.01: (0.5, 246.63)

# %%
results_cot_3b = get_success(samples_cot_3b), 631.9
# Out:
# ...
# 100%|██████████| 500/500 [00:03<00:00, 130.42it/s]

# %%
results_cot_3b
# Out:
# (0.432, 631.9)

# %%
results_spec_align_new = [0.53, 4523.0]

# %%
samples_beam_search_n4_8b = list(load_jsonl(beam_search_n4_8b))
results_beam_search_n4_8b = get_success(samples_beam_search_n4_8b),4680.9

samples_beam_search_n3_8b = list(load_jsonl(beam_search_n3_8b))
results_beam_search_n3_8b = get_success(samples_beam_search_n3_8b),6974.4

samples_beam_search_n2_8b = list(load_jsonl(beam_search_n2_8b))
results_beam_search_n2_8b = get_success(samples_beam_search_n2_8b), 4366.3

samples_best_of_n_n4_8b = list(load_jsonl(best_of_n_n4_8b))
results_best_of_n_n4_8b = get_success(samples_best_of_n_n4_8b), 773.6

samples_best_of_n_n8_8b = list(load_jsonl(best_of_n_n8_8b))
results_best_of_n_n8_8b = get_success(samples_best_of_n_n8_8b), 1378.5

samples_best_of_n_n16_8b = list(load_jsonl(best_of_n_n16_8b))
results_best_of_n_n16_8b = get_success(samples_best_of_n_n16_8b), 2708.0

samples_best_of_n_n32_8b = list(load_jsonl(best_of_n_n32_8b))
results_best_of_n_n32_8b = get_success(samples_best_of_n_n32_8b), 5520.3
# Out:
# ...
# 100%|██████████| 500/500 [00:02<00:00, 171.39it/s]

# %%
import matplotlib.pyplot as plt

# Gather results into lists
spec_align_results = [
    results_cot_3b,
    results_spec_align_n4_p1,
    results_spec_align_new
]

best_of_n_results = [
    results_best_of_n_n4_8b,
    results_best_of_n_n8_8b, 
    results_best_of_n_n16_8b,
    results_best_of_n_n32_8b
]

beam_search_results = [
    results_beam_search_n1_8b,
    results_beam_search_n2_8b,
    results_beam_search_n4_8b,
    results_beam_search_n3_8b,
]

beam_search_results_1b = [
    results_cccc,
    results_dddd,
]
beam_search_results_3b = [
    results_aaaa,
    results_bbbb,
]

# Extract accuracy and time values for beam search with different models
beam_search_1b_acc = [x[0] for x in beam_search_results_1b]
beam_search_1b_time = [x[1] for x in beam_search_results_1b]

beam_search_3b_acc = [x[0] for x in beam_search_results_3b] 
beam_search_3b_time = [x[1] for x in beam_search_results_3b]


# Extract accuracy and time values for speculative alignment
spec_align_acc = [x[0] for x in spec_align_results]
spec_align_time = [x[1] for x in spec_align_results]

# Extract accuracy and time values
best_of_n_acc = [x[0] for x in best_of_n_results]
best_of_n_time = [x[1] for x in best_of_n_results]

beam_search_acc = [x[0] for x in beam_search_results] 
beam_search_time = [x[1] for x in beam_search_results]

# Create plot
plt.figure(figsize=(10,6))
plt.plot(spec_align_time, spec_align_acc, 'go-', label='SpecAlign')
plt.plot(best_of_n_time, best_of_n_acc, 'bo-', label='Best of N')
plt.plot(beam_search_time, beam_search_acc, 'ro-', label='Beam Search 8B')
plt.plot(beam_search_1b_time, beam_search_1b_acc, 'mo-', label='Beam Search 1B')
plt.plot(beam_search_3b_time, beam_search_3b_acc, 'co-', label='Beam Search 3B')

plt.xlabel('Time (s)')
plt.ylabel('Accuracy')
plt.title('Accuracy vs Time for Different Search Methods')
plt.legend()
plt.grid(True)
plt.show()

# %%
3gb 1,5 prm, 8b-3b big, 1-3b small
